# %%
import pandas as pd
from db import DemoDB

# %%
database = DemoDB()
# Out:
# Indexing schema. This will take a second...finished!

# %%
database.tables
# Out:
# Refreshing schema. Please wait...done!
# +--------+---------------+----------------------------------------------------------------------------------+
# | Schema | Table         | Columns                                                                          |
# +--------+---------------+----------------------------------------------------------------------------------+
# | public | Album         | AlbumId, Title, ArtistId                                                         |
# | public | Artist        | ArtistId, Name                                                                   |
# | public | Customer      | CustomerId, FirstName, LastName, Company, Address, City, State, Country, PostalC |
# |        |               | ode, Phone, Fax, Email, SupportRepId                                             |
# | public | Employee      | EmployeeId, LastName, FirstName, Title, ReportsTo, BirthDate, HireDate, Address, |
# |        |               |  City, State, Country, PostalCode, Phone, Fax, Email                             |
# | public | Genre         | GenreId, Name                                                                    |
# | public | Invoice       | InvoiceId, CustomerId, InvoiceDate, BillingAddress, BillingCity, BillingState, B |
# |        |               | illingCountry, BillingPostalCode, Total                                          |
# | public | InvoiceLine   | InvoiceLineId, InvoiceId, TrackId, UnitPrice, Quantity                           |
# | public | MediaType     | MediaTypeId, Name                                                                |
# | public | Playlist      | PlaylistId, Name                                                                 |
# | public | PlaylistTrack | PlaylistId, TrackId                                                              |
# | public | Track         | TrackId, Name, AlbumId, MediaTypeId, GenreId, Composer, Milliseconds, Bytes, Uni |
# |        |               | tPrice                                                                           |
# +--------+---------------+----------------------------------------------------------------------------------+

# %%
album = database.tables.Album.all()

# %%
album.head()
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3

# %%
artist = database.tables.Artist.all()

# %%
artist.head()
# Out:
#    ArtistId               Name
# 0         1              AC/DC
# 1         2             Accept
# 2         3          Aerosmith
# 3         4  Alanis Morissette
# 4         5    Alice In Chains

# %%
album_artist = pd.merge(artist, album)

# %%
album_artist.head()
# Out:
#    ArtistId       Name  AlbumId                                  Title
# 0         1      AC/DC        1  For Those About To Rock We Salute You
# 1         1      AC/DC        4                      Let There Be Rock
# 2         2     Accept        2                      Balls to the Wall
# 3         2     Accept        3                      Restless and Wild
# 4         3  Aerosmith        5                               Big Ones

# %%
album_artist = pd.merge(artist, album, on='ArtistId')

# %%
album_artist.head()
# Out:
#    ArtistId       Name  AlbumId                                  Title
# 0         1      AC/DC        1  For Those About To Rock We Salute You
# 1         1      AC/DC        4                      Let There Be Rock
# 2         2     Accept        2                      Balls to the Wall
# 3         2     Accept        3                      Restless and Wild
# 4         3  Aerosmith        5                               Big Ones

# %%
album.rename(columns={'ArtistId': 'Artist_Id'}, inplace=True)

# %%
album.head()
# Out:
#    AlbumId                                  Title  Artist_Id
# 0        1  For Those About To Rock We Salute You          1
# 1        2                      Balls to the Wall          2
# 2        3                      Restless and Wild          2
# 3        4                      Let There Be Rock          1
# 4        5                               Big Ones          3

# %%
album_artist = pd.merge(album, artist, left_on='Artist_Id', right_on='ArtistId')

# %%
album_artist.head()
# Out:
#    AlbumId                                  Title  Artist_Id  ArtistId  \
# 0        1  For Those About To Rock We Salute You          1         1
# 1        4                      Let There Be Rock          1         1
# 2        2                      Balls to the Wall          2         2
# 3        3                      Restless and Wild          2         2
# 4        5                               Big Ones          3         3
#
#         Name
# 0      AC/DC
# 1      AC/DC
# 2     Accept
# 3     Accept
# 4  Aerosmith

# %%
pd.merge(album, artist, left_on='Artist_Id', right_on='ArtistId').drop('Artist_Id', axis=1)
# Out:
#      AlbumId                                              Title  ArtistId  \
# 0          1              For Those About To Rock We Salute You         1
# 1          4                                  Let There Be Rock         1
# 2          2                                  Balls to the Wall         2
# 3          3                                  Restless and Wild         2
# 4          5                                           Big Ones         3
# 5          6                                 Jagged Little Pill         4
# 6          7                                           Facelift         5
# 7          8                                     Warner 25 Anos         6
# 8         34                             Chill: Brazil (Disc 2)         6
# 9          9                     Plays Metallica By Four Cellos         7
# 10        10                                         Audioslave         8
# 11        11                                       Out Of Exile         8
# 12       271                                        Revelations         8
# 13        12                                BackBeat Soundtrack         9
# 14        13                           The Best Of Billy Cobham        10
# 15        14           Alcohol Fueled Brewtality Live! [Disc 1]        11
# 16        15           Alcohol Fueled Brewtality Live! [Disc 2]        11
# 17        16                                      Black Sabbath        12
# 18        17                    Black Sabbath Vol. 4 (Remaster)        12
# 19        18                                         Body Count        13
# 20        19                                   Chemical Wedding        14
# 21        20   The Best Of Buddy Guy - The Millenium Collection        15
# 22        21                                       Prenda Minha        16
# 23        22                              Sozinho Remix Ao Vivo        16
# 24        23                                     Minha Historia        17
# 25        24                                     Afrociberdelia        18
# 26        25                                    Da Lama Ao Caos        18
# 27        26                                Acústico MTV [Live]        19
# 28        27                                Cidade Negra - Hits        19
# 29        28                                           Na Pista        20
# ..       ...                                                ...       ...
# 317      320                    Mozart: Symphonies Nos. 40 & 41       248
# 318      336  Prokofiev: Symphony No.5 & Stravinksy: Le Sacr...       248
# 319      317                          Mozart Gala: Famous Arias       249
# 320      318                           SCRIABIN: Vers la flamme       250
# 321      319  Armada: Music from the Courts of England and S...       251
# 322      321                                      Back to Black       252
# 323      322                                              Frank       252
# 324      323              Carried to Dust (Bonus Track Version)       253
# 325      324          Beethoven: Symphony No. 6 'Pastoral' Etc.       254
# 326      325                   Bartok: Violin & Viola Concertos       255
# 327      326             Mendelssohn: A Midsummer Night's Dream       256
# 328      327                 Bach: Orchestral Suites Nos. 1 - 4       257
# 329      328      Charpentier: Divertissements, Airs & Concerts       258
# 330      329                             South American Getaway       259
# 331      330                            Górecki: Symphony No. 3       260
# 332      331                           Purcell: The Fairy Queen       261
# 333      332                      The Ultimate Relexation Album       262
# 334      333                  Purcell: Music for the Queen Mary       263
# 335      334                       Weill: The Seven Deadly Sins       264
# 336      335  J.S. Bach: Chaconne, Suite in E Minor, Partita...       265
# 337      337                   Szymanowski: Piano Works, Vol. 1       266
# 338      338                        Nielsen: The Six Symphonies       267
# 339      339  Great Recordings of the Century: Paganini's 24...       268
# 340      340        Liszt - 12 Études D'Execution Transcendante       269
# 341      341  Great Recordings of the Century - Shubert: Sch...       270
# 342      342  Locatelli: Concertos for Violin, Strings and C...       271
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
#                                                   Name
# 0                                                AC/DC
# 1                                                AC/DC
# 2                                               Accept
# 3                                               Accept
# 4                                            Aerosmith
# 5                                    Alanis Morissette
# 6                                      Alice In Chains
# 7                                 Antônio Carlos Jobim
# 8                                 Antônio Carlos Jobim
# 9                                         Apocalyptica
# 10                                          Audioslave
# 11                                          Audioslave
# 12                                          Audioslave
# 13                                            BackBeat
# 14                                        Billy Cobham
# 15                                 Black Label Society
# 16                                 Black Label Society
# 17                                       Black Sabbath
# 18                                       Black Sabbath
# 19                                          Body Count
# 20                                     Bruce Dickinson
# 21                                           Buddy Guy
# 22                                      Caetano Veloso
# 23                                      Caetano Veloso
# 24                                       Chico Buarque
# 25                         Chico Science & Nação Zumbi
# 26                         Chico Science & Nação Zumbi
# 27                                        Cidade Negra
# 28                                        Cidade Negra
# 29                                        Cláudio Zoli
# ..                                                 ...
# 317      Berliner Philharmoniker & Herbert Von Karajan
# 318      Berliner Philharmoniker & Herbert Von Karajan
# 319   Sir Georg Solti, Sumi Jo & Wiener Philharmoniker
# 320                                Christopher O'Riley
# 321                                           Fretwork
# 322                                      Amy Winehouse
# 323                                      Amy Winehouse
# 324                                           Calexico
# 325            Otto Klemperer & Philharmonia Orchestra
# 326                                     Yehudi Menuhin
# 327      Philharmonia Orchestra & Sir Neville Marriner
# 328  Academy of St. Martin in the Fields, Sir Nevil...
# 329            Les Arts Florissants & William Christie
# 330         The 12 Cellists of The Berlin Philharmonic
# 331                     Adrian Leaper & Doreen de Feis
# 332         Roger Norrington, London Classical Players
# 333  Charles Dutoit & L'Orchestre Symphonique de Mo...
# 334  Equale Brass Ensemble, John Eliot Gardiner & M...
# 335       Kent Nagano and Orchestre de l'Opéra de Lyon
# 336                                       Julian Bream
# 337                                      Martin Roscoe
# 338                 Göteborgs Symfoniker & Neeme Järvi
# 339                                     Itzhak Perlman
# 340                                 Michele Campanella
# 341                                       Gerald Moore
# 342   Mela Tenenbaum, Pro Musica Prague & Richard Kapp
# 343                             Emerson String Quartet
# 344  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 345                                      Nash Ensemble
# 346                              Philip Glass Ensemble
#
# [347 rows x 4 columns]

# %%
alunos1 = pd.DataFrame(
    {
        'nome': ['Maria', 'Sofia'],
        'nota': [8, 9],
    }
)
alunos2 = pd.DataFrame(
    {
        'nome': ['João', 'Pedro', 'Maria'],
        'cod': [1, 2, 3],
    }
)

# %%
alunos_total = pd.merge(alunos1, alunos2, on='nome')

# %%
alunos_total
# Out:
#     nome  nota  cod
# 0  Maria     8    3

# %%
pd.merge(alunos1, alunos2, how='outer')
# Out:
#     nome  nota  cod
# 0  Maria   8.0  3.0
# 1  Sofia   9.0  NaN
# 2   João   NaN  1.0
# 3  Pedro   NaN  2.0

# %%
pd.merge(alunos1, alunos2, how='inner')
# Out:
#     nome  nota  cod
# 0  Maria     8    3

# %%
pd.merge(alunos1, alunos2, how='left')
# Out:
#     nome  nota  cod
# 0  Maria     8  3.0
# 1  Sofia     9  NaN

# %%
pd.merge(alunos1, alunos2, how='right')
# Out:
#     nome  nota  cod
# 0  Maria   8.0    3
# 1   João   NaN    1
# 2  Pedro   NaN    2
